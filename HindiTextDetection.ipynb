# %% [markdown]
# Hindi Text Detection using Detectron 2

# %%
# !pip install -U torch==1.4+cu100 torchvision==0.5+cu100 -f https://download.pytorch.org/whl/torch_stable.html 
# !pip install cython pyyaml==5.1
# !pip install -U 'git+https://github.com/cocodataset/cocoapi.git#subdirectory=PythonAPI'
# !pip install detectron2 -f https://dl.fbaipublicfiles.com/detectron2/wheels/cu100/index.html
# Out:
# Looking in links: https://download.pytorch.org/whl/torch_stable.html
# Collecting torch==1.4+cu100
#   Downloading https://download.pytorch.org/whl/cu100/torch-1.4.0%2Bcu100-cp36-cp36m-linux_x86_64.whl (723.9MB)
#      |████████████████████████████████| 723.9MB 26kB/s
# Collecting torchvision==0.5+cu100
#   Downloading https://download.pytorch.org/whl/cu100/torchvision-0.5.0%2Bcu100-cp36-cp36m-linux_x86_64.whl (4.0MB)
#      |████████████████████████████████| 4.1MB 41.5MB/s
# Requirement already satisfied, skipping upgrade: numpy in /usr/local/lib/python3.6/dist-packages (from torchvision==0.5+cu100) (1.18.4)
# Requirement already satisfied, skipping upgrade: six in /usr/local/lib/python3.6/dist-packages (from torchvision==0.5+cu100) (1.12.0)
# Requirement already satisfied, skipping upgrade: pillow>=4.1.1 in /usr/local/lib/python3.6/dist-packages (from torchvision==0.5+cu100) (7.0.0)
# Installing collected packages: torch, torchvision
#   Found existing installation: torch 1.5.0+cu101
#     Uninstalling torch-1.5.0+cu101:
#       Successfully uninstalled torch-1.5.0+cu101
#   Found existing installation: torchvision 0.6.0+cu101
#     Uninstalling torchvision-0.6.0+cu101:
#       Successfully uninstalled torchvision-0.6.0+cu101
# Successfully installed torch-1.4.0+cu100 torchvision-0.5.0+cu100
# Requirement already satisfied: cython in /usr/local/lib/python3.6/dist-packages (0.29.18)
# Collecting pyyaml==5.1
#   Downloading https://files.pythonhosted.org/packages/9f/2c/9417b5c774792634834e730932745bc09a7d36754ca00acf1ccd1ac2594d/PyYAML-5.1.tar.gz (274kB)
#      |████████████████████████████████| 276kB 2.8MB/s
# Building wheels for collected packages: pyyaml
#   Building wheel for pyyaml (setup.py) ... done
#   Created wheel for pyyaml: filename=PyYAML-5.1-cp36-cp36m-linux_x86_64.whl size=44074 sha256=48c023925962dc8a1211191283adcd0f896a758565848121f80a3f7634659cc2
#   Stored in directory: /root/.cache/pip/wheels/ad/56/bc/1522f864feb2a358ea6f1a92b4798d69ac783a28e80567a18b
# Successfully built pyyaml
# Installing collected packages: pyyaml
#   Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
# Successfully installed pyyaml-5.1
# Collecting git+https://github.com/cocodataset/cocoapi.git#subdirectory=PythonAPI
#   Cloning https://github.com/cocodataset/cocoapi.git to /tmp/pip-req-build-3bv_2945
#   Running command git clone -q https://github.com/cocodataset/cocoapi.git /tmp/pip-req-build-3bv_2945
# Requirement already satisfied, skipping upgrade: setuptools>=18.0 in /usr/local/lib/python3.6/dist-packages (from pycocotools==2.0) (46.3.0)
# Requirement already satisfied, skipping upgrade: cython>=0.27.3 in /usr/local/lib/python3.6/dist-packages (from pycocotools==2.0) (0.29.18)
# Requirement already satisfied, skipping upgrade: matplotlib>=2.1.0 in /usr/local/lib/python3.6/dist-packages (from pycocotools==2.0) (3.2.1)
# Requirement already satisfied, skipping upgrade: numpy>=1.11 in /usr/local/lib/python3.6/dist-packages (from matplotlib>=2.1.0->pycocotools==2.0) (1.18.4)
# Requirement already satisfied, skipping upgrade: python-dateutil>=2.1 in /usr/local/lib/python3.6/dist-packages (from matplotlib>=2.1.0->pycocotools==2.0) (2.8.1)
# Requirement already satisfied, skipping upgrade: pyparsing!=2.0.4,!=2.1.2,!=2.1.6,>=2.0.1 in /usr/local/lib/python3.6/dist-packages (from matplotlib>=2.1.0->pycocotools==2.0) (2.4.7)
# Requirement already satisfied, skipping upgrade: kiwisolver>=1.0.1 in /usr/local/lib/python3.6/dist-packages (from matplotlib>=2.1.0->pycocotools==2.0) (1.2.0)
# Requirement already satisfied, skipping upgrade: cycler>=0.10 in /usr/local/lib/python3.6/dist-packages (from matplotlib>=2.1.0->pycocotools==2.0) (0.10.0)
# Requirement already satisfied, skipping upgrade: six>=1.5 in /usr/local/lib/python3.6/dist-packages (from python-dateutil>=2.1->matplotlib>=2.1.0->pycocotools==2.0) (1.12.0)
# Building wheels for collected packages: pycocotools
#   Building wheel for pycocotools (setup.py) ... done
#   Created wheel for pycocotools: filename=pycocotools-2.0-cp36-cp36m-linux_x86_64.whl size=267014 sha256=468e58d67cb6e160042e12fbfd0d0bc912b58eba33b5b06b1b06de2f50e4aa99
#   Stored in directory: /tmp/pip-ephem-wheel-cache-0hh_z26t/wheels/90/51/41/646daf401c3bc408ff10de34ec76587a9b3ebfac8d21ca5c3a
# Successfully built pycocotools
# Installing collected packages: pycocotools
#   Found existing installation: pycocotools 2.0.0
#     Uninstalling pycocotools-2.0.0:
#       Successfully uninstalled pycocotools-2.0.0
# Successfully installed pycocotools-2.0
# Looking in links: https://dl.fbaipublicfiles.com/detectron2/wheels/cu100/index.html
# Collecting detectron2
#   Downloading https://dl.fbaipublicfiles.com/detectron2/wheels/cu100/torch1.4/detectron2-0.1.3%2Bcu100-cp36-cp36m-linux_x86_64.whl (5.9MB)
#      |████████████████████████████████| 5.9MB 555kB/s
# Requirement already satisfied: tensorboard in /usr/local/lib/python3.6/dist-packages (from detectron2) (2.2.1)
# Requirement already satisfied: future in /usr/local/lib/python3.6/dist-packages (from detectron2) (0.16.0)
# Requirement already satisfied: tqdm>4.29.0 in /usr/local/lib/python3.6/dist-packages (from detectron2) (4.41.1)
# Requirement already satisfied: pydot in /usr/local/lib/python3.6/dist-packages (from detectron2) (1.3.0)
# Collecting yacs>=0.1.6
#   Downloading https://files.pythonhosted.org/packages/81/3b/40e876afde9f5ffa1cfdce10565aba85b0dc2e067ed551dfb566cfee6d4d/yacs-0.1.7-py3-none-any.whl
# Requirement already satisfied: tabulate in /usr/local/lib/python3.6/dist-packages (from detectron2) (0.8.7)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.6/dist-packages (from detectron2) (7.0.0)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.6/dist-packages (from detectron2) (1.3.0)
# Requirement already satisfied: termcolor>=1.1 in /usr/local/lib/python3.6/dist-packages (from detectron2) (1.1.0)
# Collecting mock
#   Downloading https://files.pythonhosted.org/packages/cd/74/d72daf8dff5b6566db857cfd088907bb0355f5dd2914c4b3ef065c790735/mock-4.0.2-py3-none-any.whl
# Collecting fvcore>=0.1.1
#   Downloading https://files.pythonhosted.org/packages/43/3a/50bb1e1b1acbf5e9b79f9f0c078cd3e9694e453a61cd0f07cc8dd1e1872f/fvcore-0.1.1.post200513.tar.gz
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.6/dist-packages (from detectron2) (3.2.1)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.6/dist-packages (from tensorboard->detectron2) (46.3.0)
# Requirement already satisfied: protobuf>=3.6.0 in /usr/local/lib/python3.6/dist-packages (from tensorboard->detectron2) (3.10.0)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.6/dist-packages (from tensorboard->detectron2) (0.4.1)
# Requirement already satisfied: wheel>=0.26; python_version >= "3" in /usr/local/lib/python3.6/dist-packages (from tensorboard->detectron2) (0.34.2)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.6/dist-packages (from tensorboard->detectron2) (2.23.0)
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.6/dist-packages (from tensorboard->detectron2) (1.12.0)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.6/dist-packages (from tensorboard->detectron2) (1.6.0.post3)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.6/dist-packages (from tensorboard->detectron2) (1.0.1)
# Requirement already satisfied: grpcio>=1.24.3 in /usr/local/lib/python3.6/dist-packages (from tensorboard->detectron2) (1.29.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.6/dist-packages (from tensorboard->detectron2) (3.2.2)
# Requirement already satisfied: numpy>=1.12.0 in /usr/local/lib/python3.6/dist-packages (from tensorboard->detectron2) (1.18.4)
# Requirement already satisfied: google-auth<2,>=1.6.3 in /usr/local/lib/python3.6/dist-packages (from tensorboard->detectron2) (1.7.2)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.6/dist-packages (from tensorboard->detectron2) (0.9.0)
# Requirement already satisfied: pyparsing>=2.1.4 in /usr/local/lib/python3.6/dist-packages (from pydot->detectron2) (2.4.7)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.6/dist-packages (from yacs>=0.1.6->detectron2) (5.1)
# Collecting portalocker
#   Downloading https://files.pythonhosted.org/packages/53/84/7b3146ec6378d28abc73ab484f09f47dfa008ad6f03f33d90a369f880e25/portalocker-1.7.0-py2.py3-none-any.whl
# Requirement already satisfied: python-dateutil>=2.1 in /usr/local/lib/python3.6/dist-packages (from matplotlib->detectron2) (2.8.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.6/dist-packages (from matplotlib->detectron2) (0.10.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.6/dist-packages (from matplotlib->detectron2) (1.2.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.6/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard->detectron2) (1.3.0)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests<3,>=2.21.0->tensorboard->detectron2) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests<3,>=2.21.0->tensorboard->detectron2) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests<3,>=2.21.0->tensorboard->detectron2) (2.9)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests<3,>=2.21.0->tensorboard->detectron2) (2020.4.5.1)
# Requirement already satisfied: importlib-metadata; python_version < "3.8" in /usr/local/lib/python3.6/dist-packages (from markdown>=2.6.8->tensorboard->detectron2) (1.6.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.6/dist-packages (from google-auth<2,>=1.6.3->tensorboard->detectron2) (0.2.8)
# Requirement already satisfied: cachetools<3.2,>=2.0.0 in /usr/local/lib/python3.6/dist-packages (from google-auth<2,>=1.6.3->tensorboard->detectron2) (3.1.1)
# Requirement already satisfied: rsa<4.1,>=3.1.4 in /usr/local/lib/python3.6/dist-packages (from google-auth<2,>=1.6.3->tensorboard->detectron2) (4.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.6/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard->detectron2) (3.1.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.6/dist-packages (from importlib-metadata; python_version < "3.8"->markdown>=2.6.8->tensorboard->detectron2) (3.1.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.6/dist-packages (from pyasn1-modules>=0.2.1->google-auth<2,>=1.6.3->tensorboard->detectron2) (0.4.8)
# Building wheels for collected packages: fvcore
#   Building wheel for fvcore (setup.py) ... done
#   Created wheel for fvcore: filename=fvcore-0.1.1.post200513-cp36-none-any.whl size=40893 sha256=e741eb7d42adf597a34ea0697fc9dd09d2561b65ad5efa9e6ec17b7392be8675
#   Stored in directory: /root/.cache/pip/wheels/a2/f6/77/551770c4b8cd75e9335cd0acf59c08d60a8684048b19da6702
# Successfully built fvcore
# Installing collected packages: yacs, mock, portalocker, fvcore, detectron2
# Successfully installed detectron2-0.1.3+cu100 fvcore-0.1.1.post200513 mock-4.0.2 portalocker-1.7.0 yacs-0.1.7

# %%
#mount the google drive and then run this command
# !unzip "/content/drive/My Drive/GUVI_Capstone/detectron2-master.zip"
# Out:
# Archive:  /content/drive/My Drive/GUVI_Capstone/detectron2-master.zip
# 576cf9a5da8592f9aa6379e9f4b5592042d46488
#    creating: detectron2-master/
#    creating: detectron2-master/.circleci/
#   inflating: detectron2-master/.circleci/config.yml
#   inflating: detectron2-master/.clang-format
#   inflating: detectron2-master/.flake8
#    creating: detectron2-master/.github/
#   inflating: detectron2-master/.github/CODE_OF_CONDUCT.md
#   inflating: detectron2-master/.github/CONTRIBUTING.md
#   inflating: detectron2-master/.github/Detectron2-Logo-Horz.svg
#   inflating: detectron2-master/.github/ISSUE_TEMPLATE.md
#    creating: detectron2-master/.github/ISSUE_TEMPLATE/
#  extracting: detectron2-master/.github/ISSUE_TEMPLATE/config.yml
#   inflating: detectron2-master/.github/ISSUE_TEMPLATE/feature-request.md
#   inflating: detectron2-master/.github/ISSUE_TEMPLATE/questions-help-support.md
#   inflating: detectron2-master/.github/ISSUE_TEMPLATE/unexpected-problems-bugs.md
#   inflating: detectron2-master/.github/pull_request_template.md
#   inflating: detectron2-master/.gitignore
#   inflating: detectron2-master/GETTING_STARTED.md
#   inflating: detectron2-master/INSTALL.md
#   inflating: detectron2-master/LICENSE
#   inflating: detectron2-master/MODEL_ZOO.md
#   inflating: detectron2-master/README.md
#    creating: detectron2-master/configs/
#   inflating: detectron2-master/configs/Base-RCNN-C4.yaml
#   inflating: detectron2-master/configs/Base-RCNN-DilatedC5.yaml
#   inflating: detectron2-master/configs/Base-RCNN-FPN.yaml
#   inflating: detectron2-master/configs/Base-RetinaNet.yaml
#    creating: detectron2-master/configs/COCO-Detection/
#   inflating: detectron2-master/configs/COCO-Detection/fast_rcnn_R_50_FPN_1x.yaml
#   inflating: detectron2-master/configs/COCO-Detection/faster_rcnn_R_101_C4_3x.yaml
#   inflating: detectron2-master/configs/COCO-Detection/faster_rcnn_R_101_DC5_3x.yaml
#   inflating: detectron2-master/configs/COCO-Detection/faster_rcnn_R_101_FPN_3x.yaml
#   inflating: detectron2-master/configs/COCO-Detection/faster_rcnn_R_50_C4_1x.yaml
#   inflating: detectron2-master/configs/COCO-Detection/faster_rcnn_R_50_C4_3x.yaml
#   inflating: detectron2-master/configs/COCO-Detection/faster_rcnn_R_50_DC5_1x.yaml
#   inflating: detectron2-master/configs/COCO-Detection/faster_rcnn_R_50_DC5_3x.yaml
#   inflating: detectron2-master/configs/COCO-Detection/faster_rcnn_R_50_FPN_1x.yaml
#   inflating: detectron2-master/configs/COCO-Detection/faster_rcnn_R_50_FPN_3x.yaml
#   inflating: detectron2-master/configs/COCO-Detection/faster_rcnn_X_101_32x8d_FPN_3x.yaml
#   inflating: detectron2-master/configs/COCO-Detection/retinanet_R_101_FPN_3x.yaml
#   inflating: detectron2-master/configs/COCO-Detection/retinanet_R_50_FPN_1x.yaml
#   inflating: detectron2-master/configs/COCO-Detection/retinanet_R_50_FPN_3x.yaml
#   inflating: detectron2-master/configs/COCO-Detection/rpn_R_50_C4_1x.yaml
#   inflating: detectron2-master/configs/COCO-Detection/rpn_R_50_FPN_1x.yaml
#    creating: detectron2-master/configs/COCO-InstanceSegmentation/
#   inflating: detectron2-master/configs/COCO-InstanceSegmentation/mask_rcnn_R_101_C4_3x.yaml
#   inflating: detectron2-master/configs/COCO-InstanceSegmentation/mask_rcnn_R_101_DC5_3x.yaml
#   inflating: detectron2-master/configs/COCO-InstanceSegmentation/mask_rcnn_R_101_FPN_3x.yaml
#   inflating: detectron2-master/configs/COCO-InstanceSegmentation/mask_rcnn_R_50_C4_1x.yaml
#   inflating: detectron2-master/configs/COCO-InstanceSegmentation/mask_rcnn_R_50_C4_3x.yaml
#   inflating: detectron2-master/configs/COCO-InstanceSegmentation/mask_rcnn_R_50_DC5_1x.yaml
#   inflating: detectron2-master/configs/COCO-InstanceSegmentation/mask_rcnn_R_50_DC5_3x.yaml
#   inflating: detectron2-master/configs/COCO-InstanceSegmentation/mask_rcnn_R_50_FPN_1x.yaml
#   inflating: detectron2-master/configs/COCO-InstanceSegmentation/mask_rcnn_R_50_FPN_3x.yaml
#   inflating: detectron2-master/configs/COCO-InstanceSegmentation/mask_rcnn_X_101_32x8d_FPN_3x.yaml
#    creating: detectron2-master/configs/COCO-Keypoints/
#   inflating: detectron2-master/configs/COCO-Keypoints/Base-Keypoint-RCNN-FPN.yaml
#   inflating: detectron2-master/configs/COCO-Keypoints/keypoint_rcnn_R_101_FPN_3x.yaml
#   inflating: detectron2-master/configs/COCO-Keypoints/keypoint_rcnn_R_50_FPN_1x.yaml
#   inflating: detectron2-master/configs/COCO-Keypoints/keypoint_rcnn_R_50_FPN_3x.yaml
#   inflating: detectron2-master/configs/COCO-Keypoints/keypoint_rcnn_X_101_32x8d_FPN_3x.yaml
#    creating: detectron2-master/configs/COCO-PanopticSegmentation/
#   inflating: detectron2-master/configs/COCO-PanopticSegmentation/Base-Panoptic-FPN.yaml
#   inflating: detectron2-master/configs/COCO-PanopticSegmentation/panoptic_fpn_R_101_3x.yaml
#   inflating: detectron2-master/configs/COCO-PanopticSegmentation/panoptic_fpn_R_50_1x.yaml
#   inflating: detectron2-master/configs/COCO-PanopticSegmentation/panoptic_fpn_R_50_3x.yaml
#    creating: detectron2-master/configs/Cityscapes/
#   inflating: detectron2-master/configs/Cityscapes/mask_rcnn_R_50_FPN.yaml
#    creating: detectron2-master/configs/Detectron1-Comparisons/
#   inflating: detectron2-master/configs/Detectron1-Comparisons/README.md
#   inflating: detectron2-master/configs/Detectron1-Comparisons/faster_rcnn_R_50_FPN_noaug_1x.yaml
#   inflating: detectron2-master/configs/Detectron1-Comparisons/keypoint_rcnn_R_50_FPN_1x.yaml
#   inflating: detectron2-master/configs/Detectron1-Comparisons/mask_rcnn_R_50_FPN_noaug_1x.yaml
#    creating: detectron2-master/configs/LVIS-InstanceSegmentation/
#   inflating: detectron2-master/configs/LVIS-InstanceSegmentation/mask_rcnn_R_101_FPN_1x.yaml
#   inflating: detectron2-master/configs/LVIS-InstanceSegmentation/mask_rcnn_R_50_FPN_1x.yaml
#   inflating: detectron2-master/configs/LVIS-InstanceSegmentation/mask_rcnn_X_101_32x8d_FPN_1x.yaml
#    creating: detectron2-master/configs/Misc/
#   inflating: detectron2-master/configs/Misc/cascade_mask_rcnn_R_50_FPN_1x.yaml
#   inflating: detectron2-master/configs/Misc/cascade_mask_rcnn_R_50_FPN_3x.yaml
#   inflating: detectron2-master/configs/Misc/cascade_mask_rcnn_X_152_32x8d_FPN_IN5k_gn_dconv.yaml
#   inflating: detectron2-master/configs/Misc/mask_rcnn_R_50_FPN_1x_cls_agnostic.yaml
#   inflating: detectron2-master/configs/Misc/mask_rcnn_R_50_FPN_1x_dconv_c3-c5.yaml
#   inflating: detectron2-master/configs/Misc/mask_rcnn_R_50_FPN_3x_dconv_c3-c5.yaml
#   inflating: detectron2-master/configs/Misc/mask_rcnn_R_50_FPN_3x_gn.yaml
#   inflating: detectron2-master/configs/Misc/mask_rcnn_R_50_FPN_3x_syncbn.yaml
#   inflating: detectron2-master/configs/Misc/panoptic_fpn_R_101_dconv_cascade_gn_3x.yaml
#   inflating: detectron2-master/configs/Misc/scratch_mask_rcnn_R_50_FPN_3x_gn.yaml
#   inflating: detectron2-master/configs/Misc/semantic_R_50_FPN_1x.yaml
#    creating: detectron2-master/configs/PascalVOC-Detection/
#   inflating: detectron2-master/configs/PascalVOC-Detection/faster_rcnn_R_50_C4.yaml
#   inflating: detectron2-master/configs/PascalVOC-Detection/faster_rcnn_R_50_FPN.yaml
#    creating: detectron2-master/configs/quick_schedules/
#   inflating: detectron2-master/configs/quick_schedules/README.md
#   inflating: detectron2-master/configs/quick_schedules/cascade_mask_rcnn_R_50_FPN_inference_acc_test.yaml
#   inflating: detectron2-master/configs/quick_schedules/cascade_mask_rcnn_R_50_FPN_instant_test.yaml
#   inflating: detectron2-master/configs/quick_schedules/fast_rcnn_R_50_FPN_inference_acc_test.yaml
#   inflating: detectron2-master/configs/quick_schedules/fast_rcnn_R_50_FPN_instant_test.yaml
#   inflating: detectron2-master/configs/quick_schedules/keypoint_rcnn_R_50_FPN_inference_acc_test.yaml
#   inflating: detectron2-master/configs/quick_schedules/keypoint_rcnn_R_50_FPN_instant_test.yaml
#   inflating: detectron2-master/configs/quick_schedules/keypoint_rcnn_R_50_FPN_normalized_training_acc_test.yaml
#   inflating: detectron2-master/configs/quick_schedules/keypoint_rcnn_R_50_FPN_training_acc_test.yaml
#   inflating: detectron2-master/configs/quick_schedules/mask_rcnn_R_50_C4_GCV_instant_test.yaml
#   inflating: detectron2-master/configs/quick_schedules/mask_rcnn_R_50_C4_inference_acc_test.yaml
#   inflating: detectron2-master/configs/quick_schedules/mask_rcnn_R_50_C4_instant_test.yaml
#   inflating: detectron2-master/configs/quick_schedules/mask_rcnn_R_50_C4_training_acc_test.yaml
#   inflating: detectron2-master/configs/quick_schedules/mask_rcnn_R_50_DC5_inference_acc_test.yaml
#   inflating: detectron2-master/configs/quick_schedules/mask_rcnn_R_50_FPN_inference_acc_test.yaml
#   inflating: detectron2-master/configs/quick_schedules/mask_rcnn_R_50_FPN_instant_test.yaml
#   inflating: detectron2-master/configs/quick_schedules/mask_rcnn_R_50_FPN_training_acc_test.yaml
#   inflating: detectron2-master/configs/quick_schedules/panoptic_fpn_R_50_inference_acc_test.yaml
#   inflating: detectron2-master/configs/quick_schedules/panoptic_fpn_R_50_instant_test.yaml
#   inflating: detectron2-master/configs/quick_schedules/panoptic_fpn_R_50_training_acc_test.yaml
#   inflating: detectron2-master/configs/quick_schedules/retinanet_R_50_FPN_inference_acc_test.yaml
#   inflating: detectron2-master/configs/quick_schedules/retinanet_R_50_FPN_instant_test.yaml
#   inflating: detectron2-master/configs/quick_schedules/rpn_R_50_FPN_inference_acc_test.yaml
#   inflating: detectron2-master/configs/quick_schedules/rpn_R_50_FPN_instant_test.yaml
#   inflating: detectron2-master/configs/quick_schedules/semantic_R_50_FPN_inference_acc_test.yaml
#   inflating: detectron2-master/configs/quick_schedules/semantic_R_50_FPN_instant_test.yaml
#   inflating: detectron2-master/configs/quick_schedules/semantic_R_50_FPN_training_acc_test.yaml
#    creating: detectron2-master/datasets/
#   inflating: detectron2-master/datasets/README.md
#   inflating: detectron2-master/datasets/prepare_cocofied_lvis.py
#   inflating: detectron2-master/datasets/prepare_for_tests.sh
#   inflating: detectron2-master/datasets/prepare_panoptic_fpn.py
#    creating: detectron2-master/demo/
#   inflating: detectron2-master/demo/README.md
#   inflating: detectron2-master/demo/demo.py
#   inflating: detectron2-master/demo/predictor.py
#    creating: detectron2-master/detectron2/
#   inflating: detectron2-master/detectron2/__init__.py
#    creating: detectron2-master/detectron2/checkpoint/
#   inflating: detectron2-master/detectron2/checkpoint/__init__.py
#   inflating: detectron2-master/detectron2/checkpoint/c2_model_loading.py
#   inflating: detectron2-master/detectron2/checkpoint/catalog.py
#   inflating: detectron2-master/detectron2/checkpoint/detection_checkpoint.py
#    creating: detectron2-master/detectron2/config/
#   inflating: detectron2-master/detectron2/config/__init__.py
#   inflating: detectron2-master/detectron2/config/compat.py
#   inflating: detectron2-master/detectron2/config/config.py
#   inflating: detectron2-master/detectron2/config/defaults.py
#    creating: detectron2-master/detectron2/data/
#   inflating: detectron2-master/detectron2/data/__init__.py
#   inflating: detectron2-master/detectron2/data/build.py
#   inflating: detectron2-master/detectron2/data/catalog.py
#   inflating: detectron2-master/detectron2/data/common.py
#   inflating: detectron2-master/detectron2/data/dataset_mapper.py
#    creating: detectron2-master/detectron2/data/datasets/
#   inflating: detectron2-master/detectron2/data/datasets/README.md
#   inflating: detectron2-master/detectron2/data/datasets/__init__.py
#   inflating: detectron2-master/detectron2/data/datasets/builtin.py
#   inflating: detectron2-master/detectron2/data/datasets/builtin_meta.py
#   inflating: detectron2-master/detectron2/data/datasets/cityscapes.py
#   inflating: detectron2-master/detectron2/data/datasets/coco.py
#   inflating: detectron2-master/detectron2/data/datasets/lvis.py
#   inflating: detectron2-master/detectron2/data/datasets/lvis_v0_5_categories.py
#   inflating: detectron2-master/detectron2/data/datasets/pascal_voc.py
#   inflating: detectron2-master/detectron2/data/datasets/register_coco.py
#   inflating: detectron2-master/detectron2/data/detection_utils.py
#    creating: detectron2-master/detectron2/data/samplers/
#   inflating: detectron2-master/detectron2/data/samplers/__init__.py
#   inflating: detectron2-master/detectron2/data/samplers/distributed_sampler.py
#   inflating: detectron2-master/detectron2/data/samplers/grouped_batch_sampler.py
#    creating: detectron2-master/detectron2/data/transforms/
#   inflating: detectron2-master/detectron2/data/transforms/__init__.py
#   inflating: detectron2-master/detectron2/data/transforms/transform.py
#   inflating: detectron2-master/detectron2/data/transforms/transform_gen.py
#    creating: detectron2-master/detectron2/engine/
#   inflating: detectron2-master/detectron2/engine/__init__.py
#   inflating: detectron2-master/detectron2/engine/defaults.py
#   inflating: detectron2-master/detectron2/engine/hooks.py
#   inflating: detectron2-master/detectron2/engine/launch.py
#   inflating: detectron2-master/detectron2/engine/train_loop.py
#    creating: detectron2-master/detectron2/evaluation/
#   inflating: detectron2-master/detectron2/evaluation/__init__.py
#   inflating: detectron2-master/detectron2/evaluation/cityscapes_evaluation.py
#   inflating: detectron2-master/detectron2/evaluation/coco_evaluation.py
#   inflating: detectron2-master/detectron2/evaluation/evaluator.py
#   inflating: detectron2-master/detectron2/evaluation/lvis_evaluation.py
#   inflating: detectron2-master/detectron2/evaluation/panoptic_evaluation.py
#   inflating: detectron2-master/detectron2/evaluation/pascal_voc_evaluation.py
#   inflating: detectron2-master/detectron2/evaluation/rotated_coco_evaluation.py
#   inflating: detectron2-master/detectron2/evaluation/sem_seg_evaluation.py
#   inflating: detectron2-master/detectron2/evaluation/testing.py
#    creating: detectron2-master/detectron2/export/
#   inflating: detectron2-master/detectron2/export/README.md
#   inflating: detectron2-master/detectron2/export/__init__.py
#   inflating: detectron2-master/detectron2/export/api.py
#   inflating: detectron2-master/detectron2/export/c10.py
#   inflating: detectron2-master/detectron2/export/caffe2_export.py
#   inflating: detectron2-master/detectron2/export/caffe2_inference.py
#   inflating: detectron2-master/detectron2/export/caffe2_modeling.py
#   inflating: detectron2-master/detectron2/export/patcher.py
#   inflating: detectron2-master/detectron2/export/shared.py
#    creating: detectron2-master/detectron2/layers/
#   inflating: detectron2-master/detectron2/layers/__init__.py
#   inflating: detectron2-master/detectron2/layers/batch_norm.py
#    creating: detectron2-master/detectron2/layers/csrc/
#   inflating: detectron2-master/detectron2/layers/csrc/README.md
#    creating: detectron2-master/detectron2/layers/csrc/ROIAlign/
#   inflating: detectron2-master/detectron2/layers/csrc/ROIAlign/ROIAlign.h
#   inflating: detectron2-master/detectron2/layers/csrc/ROIAlign/ROIAlign_cpu.cpp
#   inflating: detectron2-master/detectron2/layers/csrc/ROIAlign/ROIAlign_cuda.cu
#    creating: detectron2-master/detectron2/layers/csrc/ROIAlignRotated/
#   inflating: detectron2-master/detectron2/layers/csrc/ROIAlignRotated/ROIAlignRotated.h
#   inflating: detectron2-master/detectron2/layers/csrc/ROIAlignRotated/ROIAlignRotated_cpu.cpp
#   inflating: detectron2-master/detectron2/layers/csrc/ROIAlignRotated/ROIAlignRotated_cuda.cu
#    creating: detectron2-master/detectron2/layers/csrc/box_iou_rotated/
#   inflating: detectron2-master/detectron2/layers/csrc/box_iou_rotated/box_iou_rotated.h
#   inflating: detectron2-master/detectron2/layers/csrc/box_iou_rotated/box_iou_rotated_cpu.cpp
#   inflating: detectron2-master/detectron2/layers/csrc/box_iou_rotated/box_iou_rotated_cuda.cu
#   inflating: detectron2-master/detectron2/layers/csrc/box_iou_rotated/box_iou_rotated_utils.h
#   inflating: detectron2-master/detectron2/layers/csrc/cuda_version.cu
#    creating: detectron2-master/detectron2/layers/csrc/deformable/
#   inflating: detectron2-master/detectron2/layers/csrc/deformable/deform_conv.h
#   inflating: detectron2-master/detectron2/layers/csrc/deformable/deform_conv_cuda.cu
#   inflating: detectron2-master/detectron2/layers/csrc/deformable/deform_conv_cuda_kernel.cu
#    creating: detectron2-master/detectron2/layers/csrc/nms_rotated/
#   inflating: detectron2-master/detectron2/layers/csrc/nms_rotated/nms_rotated.h
#   inflating: detectron2-master/detectron2/layers/csrc/nms_rotated/nms_rotated_cpu.cpp
#   inflating: detectron2-master/detectron2/layers/csrc/nms_rotated/nms_rotated_cuda.cu
#   inflating: detectron2-master/detectron2/layers/csrc/vision.cpp
#   inflating: detectron2-master/detectron2/layers/deform_conv.py
#   inflating: detectron2-master/detectron2/layers/mask_ops.py
#   inflating: detectron2-master/detectron2/layers/nms.py
#   inflating: detectron2-master/detectron2/layers/roi_align.py
#   inflating: detectron2-master/detectron2/layers/roi_align_rotated.py
#   inflating: detectron2-master/detectron2/layers/rotated_boxes.py
#   inflating: detectron2-master/detectron2/layers/shape_spec.py
#   inflating: detectron2-master/detectron2/layers/wrappers.py
#    creating: detectron2-master/detectron2/model_zoo/
#   inflating: detectron2-master/detectron2/model_zoo/__init__.py
#   inflating: detectron2-master/detectron2/model_zoo/model_zoo.py
#    creating: detectron2-master/detectron2/modeling/
#   inflating: detectron2-master/detectron2/modeling/__init__.py
#   inflating: detectron2-master/detectron2/modeling/anchor_generator.py
#    creating: detectron2-master/detectron2/modeling/backbone/
#   inflating: detectron2-master/detectron2/modeling/backbone/__init__.py
#   inflating: detectron2-master/detectron2/modeling/backbone/backbone.py
#   inflating: detectron2-master/detectron2/modeling/backbone/build.py
#   inflating: detectron2-master/detectron2/modeling/backbone/fpn.py
#   inflating: detectron2-master/detectron2/modeling/backbone/resnet.py
#   inflating: detectron2-master/detectron2/modeling/box_regression.py
#   inflating: detectron2-master/detectron2/modeling/matcher.py
#    creating: detectron2-master/detectron2/modeling/meta_arch/
#   inflating: detectron2-master/detectron2/modeling/meta_arch/__init__.py
#   inflating: detectron2-master/detectron2/modeling/meta_arch/build.py
#   inflating: detectron2-master/detectron2/modeling/meta_arch/panoptic_fpn.py
#   inflating: detectron2-master/detectron2/modeling/meta_arch/rcnn.py
#   inflating: detectron2-master/detectron2/modeling/meta_arch/retinanet.py
#   inflating: detectron2-master/detectron2/modeling/meta_arch/semantic_seg.py
#   inflating: detectron2-master/detectron2/modeling/poolers.py
#   inflating: detectron2-master/detectron2/modeling/postprocessing.py
#    creating: detectron2-master/detectron2/modeling/proposal_generator/
#   inflating: detectron2-master/detectron2/modeling/proposal_generator/__init__.py
#   inflating: detectron2-master/detectron2/modeling/proposal_generator/build.py
#   inflating: detectron2-master/detectron2/modeling/proposal_generator/proposal_utils.py
#   inflating: detectron2-master/detectron2/modeling/proposal_generator/rpn.py
#   inflating: detectron2-master/detectron2/modeling/proposal_generator/rpn_outputs.py
#   inflating: detectron2-master/detectron2/modeling/proposal_generator/rrpn.py
#   inflating: detectron2-master/detectron2/modeling/proposal_generator/rrpn_outputs.py
#    creating: detectron2-master/detectron2/modeling/roi_heads/
#   inflating: detectron2-master/detectron2/modeling/roi_heads/__init__.py
#   inflating: detectron2-master/detectron2/modeling/roi_heads/box_head.py
#   inflating: detectron2-master/detectron2/modeling/roi_heads/cascade_rcnn.py
#   inflating: detectron2-master/detectron2/modeling/roi_heads/fast_rcnn.py
#   inflating: detectron2-master/detectron2/modeling/roi_heads/keypoint_head.py
#   inflating: detectron2-master/detectron2/modeling/roi_heads/mask_head.py
#   inflating: detectron2-master/detectron2/modeling/roi_heads/roi_heads.py
#   inflating: detectron2-master/detectron2/modeling/roi_heads/rotated_fast_rcnn.py
#   inflating: detectron2-master/detectron2/modeling/sampling.py
#   inflating: detectron2-master/detectron2/modeling/test_time_augmentation.py
#    creating: detectron2-master/detectron2/solver/
#   inflating: detectron2-master/detectron2/solver/__init__.py
#   inflating: detectron2-master/detectron2/solver/build.py
#   inflating: detectron2-master/detectron2/solver/lr_scheduler.py
#    creating: detectron2-master/detectron2/structures/
#   inflating: detectron2-master/detectron2/structures/__init__.py
#   inflating: detectron2-master/detectron2/structures/boxes.py
#   inflating: detectron2-master/detectron2/structures/image_list.py
#   inflating: detectron2-master/detectron2/structures/instances.py
#   inflating: detectron2-master/detectron2/structures/keypoints.py
#   inflating: detectron2-master/detectron2/structures/masks.py
#   inflating: detectron2-master/detectron2/structures/rotated_boxes.py
#    creating: detectron2-master/detectron2/utils/
#   inflating: detectron2-master/detectron2/utils/README.md
#  extracting: detectron2-master/detectron2/utils/__init__.py
#   inflating: detectron2-master/detectron2/utils/analysis.py
#   inflating: detectron2-master/detectron2/utils/collect_env.py
#   inflating: detectron2-master/detectron2/utils/colormap.py
#   inflating: detectron2-master/detectron2/utils/comm.py
#   inflating: detectron2-master/detectron2/utils/env.py
#   inflating: detectron2-master/detectron2/utils/events.py
#   inflating: detectron2-master/detectron2/utils/logger.py
#   inflating: detectron2-master/detectron2/utils/memory.py
#   inflating: detectron2-master/detectron2/utils/registry.py
#   inflating: detectron2-master/detectron2/utils/serialize.py
#   inflating: detectron2-master/detectron2/utils/video_visualizer.py
#   inflating: detectron2-master/detectron2/utils/visualizer.py
#    creating: detectron2-master/dev/
#   inflating: detectron2-master/dev/README.md
#   inflating: detectron2-master/dev/linter.sh
#    creating: detectron2-master/dev/packaging/
#   inflating: detectron2-master/dev/packaging/README.md
#   inflating: detectron2-master/dev/packaging/build_all_wheels.sh
#   inflating: detectron2-master/dev/packaging/build_wheel.sh
#   inflating: detectron2-master/dev/packaging/gen_wheel_index.sh
#   inflating: detectron2-master/dev/packaging/pkg_helpers.bash
#   inflating: detectron2-master/dev/parse_results.sh
#   inflating: detectron2-master/dev/run_inference_tests.sh
#   inflating: detectron2-master/dev/run_instant_tests.sh
#    creating: detectron2-master/docker/
#   inflating: detectron2-master/docker/Dockerfile
#   inflating: detectron2-master/docker/Dockerfile-circleci
#   inflating: detectron2-master/docker/README.md
#   inflating: detectron2-master/docker/docker-compose.yml
#    creating: detectron2-master/docs/
#  extracting: detectron2-master/docs/.gitignore
#   inflating: detectron2-master/docs/Makefile
#   inflating: detectron2-master/docs/README.md
#   inflating: detectron2-master/docs/conf.py
#   inflating: detectron2-master/docs/index.rst
#    creating: detectron2-master/docs/modules/
#   inflating: detectron2-master/docs/modules/checkpoint.rst
#   inflating: detectron2-master/docs/modules/config.rst
#   inflating: detectron2-master/docs/modules/data.rst
#   inflating: detectron2-master/docs/modules/engine.rst
#   inflating: detectron2-master/docs/modules/evaluation.rst
#   inflating: detectron2-master/docs/modules/export.rst
#   inflating: detectron2-master/docs/modules/index.rst
#   inflating: detectron2-master/docs/modules/layers.rst
#   inflating: detectron2-master/docs/modules/model_zoo.rst
#   inflating: detectron2-master/docs/modules/modeling.rst
#   inflating: detectron2-master/docs/modules/solver.rst
#   inflating: detectron2-master/docs/modules/structures.rst
#   inflating: detectron2-master/docs/modules/utils.rst
#    creating: detectron2-master/docs/notes/
#   inflating: detectron2-master/docs/notes/benchmarks.md
#   inflating: detectron2-master/docs/notes/changelog.md
#   inflating: detectron2-master/docs/notes/compatibility.md
#     linking: detectron2-master/docs/notes/contributing.md  -> ../../.github/CONTRIBUTING.md
#   inflating: detectron2-master/docs/notes/index.rst
#   inflating: detectron2-master/docs/requirements.txt
#    creating: detectron2-master/docs/tutorials/
#   inflating: detectron2-master/docs/tutorials/README.md
#   inflating: detectron2-master/docs/tutorials/configs.md
#   inflating: detectron2-master/docs/tutorials/data_loading.md
#   inflating: detectron2-master/docs/tutorials/datasets.md
#   inflating: detectron2-master/docs/tutorials/deployment.md
#   inflating: detectron2-master/docs/tutorials/evaluation.md
#   inflating: detectron2-master/docs/tutorials/extend.md
#     linking: detectron2-master/docs/tutorials/getting_started.md  -> ../../GETTING_STARTED.md
#   inflating: detectron2-master/docs/tutorials/index.rst
#     linking: detectron2-master/docs/tutorials/install.md  -> ../../INSTALL.md
#   inflating: detectron2-master/docs/tutorials/models.md
#   inflating: detectron2-master/docs/tutorials/training.md
#   inflating: detectron2-master/docs/tutorials/write-models.md
#    creating: detectron2-master/projects/
#    creating: detectron2-master/projects/DensePose/
#   inflating: detectron2-master/projects/DensePose/README.md
#   inflating: detectron2-master/projects/DensePose/apply_net.py
#    creating: detectron2-master/projects/DensePose/configs/
#   inflating: detectron2-master/projects/DensePose/configs/Base-DensePose-RCNN-FPN.yaml
#   inflating: detectron2-master/projects/DensePose/configs/densepose_rcnn_R_101_FPN_DL_WC1_s1x.yaml
#   inflating: detectron2-master/projects/DensePose/configs/densepose_rcnn_R_101_FPN_DL_WC2_s1x.yaml
#   inflating: detectron2-master/projects/DensePose/configs/densepose_rcnn_R_101_FPN_DL_s1x.yaml
#   inflating: detectron2-master/projects/DensePose/configs/densepose_rcnn_R_101_FPN_WC1_s1x.yaml
#   inflating: detectron2-master/projects/DensePose/configs/densepose_rcnn_R_101_FPN_WC2_s1x.yaml
#   inflating: detectron2-master/projects/DensePose/configs/densepose_rcnn_R_101_FPN_s1x.yaml
#   inflating: detectron2-master/projects/DensePose/configs/densepose_rcnn_R_101_FPN_s1x_legacy.yaml
#   inflating: detectron2-master/projects/DensePose/configs/densepose_rcnn_R_50_FPN_DL_WC1_s1x.yaml
#   inflating: detectron2-master/projects/DensePose/configs/densepose_rcnn_R_50_FPN_DL_WC2_s1x.yaml
#   inflating: detectron2-master/projects/DensePose/configs/densepose_rcnn_R_50_FPN_DL_s1x.yaml
#   inflating: detectron2-master/projects/DensePose/configs/densepose_rcnn_R_50_FPN_WC1_s1x.yaml
#   inflating: detectron2-master/projects/DensePose/configs/densepose_rcnn_R_50_FPN_WC2_s1x.yaml
#   inflating: detectron2-master/projects/DensePose/configs/densepose_rcnn_R_50_FPN_s1x.yaml
#   inflating: detectron2-master/projects/DensePose/configs/densepose_rcnn_R_50_FPN_s1x_legacy.yaml
#    creating: detectron2-master/projects/DensePose/configs/quick_schedules/
#   inflating: detectron2-master/projects/DensePose/configs/quick_schedules/densepose_rcnn_R_50_FPN_DL_instant_test.yaml
#   inflating: detectron2-master/projects/DensePose/configs/quick_schedules/densepose_rcnn_R_50_FPN_TTA_inference_acc_test.yaml
#   inflating: detectron2-master/projects/DensePose/configs/quick_schedules/densepose_rcnn_R_50_FPN_WC1_instant_test.yaml
#   inflating: detectron2-master/projects/DensePose/configs/quick_schedules/densepose_rcnn_R_50_FPN_WC2_instant_test.yaml
#   inflating: detectron2-master/projects/DensePose/configs/quick_schedules/densepose_rcnn_R_50_FPN_inference_acc_test.yaml
#   inflating: detectron2-master/projects/DensePose/configs/quick_schedules/densepose_rcnn_R_50_FPN_instant_test.yaml
#   inflating: detectron2-master/projects/DensePose/configs/quick_schedules/densepose_rcnn_R_50_FPN_training_acc_test.yaml
#    creating: detectron2-master/projects/DensePose/densepose/
#   inflating: detectron2-master/projects/DensePose/densepose/__init__.py
#   inflating: detectron2-master/projects/DensePose/densepose/config.py
#   inflating: detectron2-master/projects/DensePose/densepose/dataset.py
#   inflating: detectron2-master/projects/DensePose/densepose/dataset_mapper.py
#   inflating: detectron2-master/projects/DensePose/densepose/densepose_coco_evaluation.py
#   inflating: detectron2-master/projects/DensePose/densepose/densepose_head.py
#   inflating: detectron2-master/projects/DensePose/densepose/evaluator.py
#    creating: detectron2-master/projects/DensePose/densepose/modeling/
#   inflating: detectron2-master/projects/DensePose/densepose/modeling/test_time_augmentation.py
#   inflating: detectron2-master/projects/DensePose/densepose/roi_head.py
#   inflating: detectron2-master/projects/DensePose/densepose/structures.py
#    creating: detectron2-master/projects/DensePose/densepose/utils/
#   inflating: detectron2-master/projects/DensePose/densepose/utils/dbhelper.py
#   inflating: detectron2-master/projects/DensePose/densepose/utils/logger.py
#   inflating: detectron2-master/projects/DensePose/densepose/utils/transform.py
#    creating: detectron2-master/projects/DensePose/densepose/vis/
#   inflating: detectron2-master/projects/DensePose/densepose/vis/base.py
#   inflating: detectron2-master/projects/DensePose/densepose/vis/bounding_box.py
#   inflating: detectron2-master/projects/DensePose/densepose/vis/densepose.py
#   inflating: detectron2-master/projects/DensePose/densepose/vis/extractor.py
#    creating: detectron2-master/projects/DensePose/dev/
#   inflating: detectron2-master/projects/DensePose/dev/README.md
#   inflating: detectron2-master/projects/DensePose/dev/run_inference_tests.sh
#   inflating: detectron2-master/projects/DensePose/dev/run_instant_tests.sh
#    creating: detectron2-master/projects/DensePose/doc/
#   inflating: detectron2-master/projects/DensePose/doc/GETTING_STARTED.md
#   inflating: detectron2-master/projects/DensePose/doc/MODEL_ZOO.md
#   inflating: detectron2-master/projects/DensePose/doc/TOOL_APPLY_NET.md
#   inflating: detectron2-master/projects/DensePose/doc/TOOL_QUERY_DB.md
#    creating: detectron2-master/projects/DensePose/doc/images/
#   inflating: detectron2-master/projects/DensePose/doc/images/res_bbox_dp_contour.jpg
#   inflating: detectron2-master/projects/DensePose/doc/images/res_bbox_dp_segm.jpg
#   inflating: detectron2-master/projects/DensePose/doc/images/res_bbox_dp_u.jpg
#   inflating: detectron2-master/projects/DensePose/doc/images/res_bbox_dp_v.jpg
#   inflating: detectron2-master/projects/DensePose/doc/images/vis_bbox_dp_i.jpg
#   inflating: detectron2-master/projects/DensePose/doc/images/vis_bbox_dp_pts.jpg
#   inflating: detectron2-master/projects/DensePose/doc/images/vis_bbox_dp_segm.jpg
#   inflating: detectron2-master/projects/DensePose/doc/images/vis_bbox_dp_u.jpg
#   inflating: detectron2-master/projects/DensePose/doc/images/vis_bbox_dp_v.jpg
#   inflating: detectron2-master/projects/DensePose/query_db.py
#    creating: detectron2-master/projects/DensePose/tests/
#   inflating: detectron2-master/projects/DensePose/tests/common.py
#   inflating: detectron2-master/projects/DensePose/tests/test_model_e2e.py
#   inflating: detectron2-master/projects/DensePose/tests/test_setup.py
#   inflating: detectron2-master/projects/DensePose/tests/test_structures.py
#   inflating: detectron2-master/projects/DensePose/train_net.py
#    creating: detectron2-master/projects/PointRend/
#   inflating: detectron2-master/projects/PointRend/README.md
#    creating: detectron2-master/projects/PointRend/configs/
#    creating: detectron2-master/projects/PointRend/configs/InstanceSegmentation/
#   inflating: detectron2-master/projects/PointRend/configs/InstanceSegmentation/Base-PointRend-RCNN-FPN.yaml
#   inflating: detectron2-master/projects/PointRend/configs/InstanceSegmentation/pointrend_rcnn_R_50_FPN_1x_cityscapes.yaml
#   inflating: detectron2-master/projects/PointRend/configs/InstanceSegmentation/pointrend_rcnn_R_50_FPN_1x_coco.yaml
#   inflating: detectron2-master/projects/PointRend/configs/InstanceSegmentation/pointrend_rcnn_R_50_FPN_3x_coco.yaml
#    creating: detectron2-master/projects/PointRend/point_rend/
#   inflating: detectron2-master/projects/PointRend/point_rend/__init__.py
#   inflating: detectron2-master/projects/PointRend/point_rend/coarse_mask_head.py
#   inflating: detectron2-master/projects/PointRend/point_rend/config.py
#   inflating: detectron2-master/projects/PointRend/point_rend/point_features.py
#   inflating: detectron2-master/projects/PointRend/point_rend/point_head.py
#   inflating: detectron2-master/projects/PointRend/point_rend/roi_heads.py
#   inflating: detectron2-master/projects/PointRend/train_net.py
#   inflating: detectron2-master/projects/README.md
#    creating: detectron2-master/projects/TensorMask/
#   inflating: detectron2-master/projects/TensorMask/README.md
#    creating: detectron2-master/projects/TensorMask/configs/
#   inflating: detectron2-master/projects/TensorMask/configs/Base-TensorMask.yaml
#   inflating: detectron2-master/projects/TensorMask/configs/tensormask_R_50_FPN_1x.yaml
#   inflating: detectron2-master/projects/TensorMask/configs/tensormask_R_50_FPN_6x.yaml
#   inflating: detectron2-master/projects/TensorMask/setup.py
#    creating: detectron2-master/projects/TensorMask/tensormask/
#   inflating: detectron2-master/projects/TensorMask/tensormask/__init__.py
#   inflating: detectron2-master/projects/TensorMask/tensormask/arch.py
#   inflating: detectron2-master/projects/TensorMask/tensormask/config.py
#    creating: detectron2-master/projects/TensorMask/tensormask/layers/
#   inflating: detectron2-master/projects/TensorMask/tensormask/layers/__init__.py
#    creating: detectron2-master/projects/TensorMask/tensormask/layers/csrc/
#    creating: detectron2-master/projects/TensorMask/tensormask/layers/csrc/SwapAlign2Nat/
#   inflating: detectron2-master/projects/TensorMask/tensormask/layers/csrc/SwapAlign2Nat/SwapAlign2Nat.h
#   inflating: detectron2-master/projects/TensorMask/tensormask/layers/csrc/SwapAlign2Nat/SwapAlign2Nat_cuda.cu
#   inflating: detectron2-master/projects/TensorMask/tensormask/layers/csrc/vision.cpp
#   inflating: detectron2-master/projects/TensorMask/tensormask/layers/swap_align2nat.py
#    creating: detectron2-master/projects/TensorMask/tests/
#  extracting: detectron2-master/projects/TensorMask/tests/__init__.py
#   inflating: detectron2-master/projects/TensorMask/tests/test_swap_align2nat.py
#   inflating: detectron2-master/projects/TensorMask/train_net.py
#    creating: detectron2-master/projects/TridentNet/
#   inflating: detectron2-master/projects/TridentNet/README.md
#    creating: detectron2-master/projects/TridentNet/configs/
#   inflating: detectron2-master/projects/TridentNet/configs/Base-TridentNet-Fast-C4.yaml
#   inflating: detectron2-master/projects/TridentNet/configs/tridentnet_fast_R_101_C4_3x.yaml
#   inflating: detectron2-master/projects/TridentNet/configs/tridentnet_fast_R_50_C4_1x.yaml
#   inflating: detectron2-master/projects/TridentNet/configs/tridentnet_fast_R_50_C4_3x.yaml
#   inflating: detectron2-master/projects/TridentNet/train_net.py
#    creating: detectron2-master/projects/TridentNet/tridentnet/
#   inflating: detectron2-master/projects/TridentNet/tridentnet/__init__.py
#   inflating: detectron2-master/projects/TridentNet/tridentnet/config.py
#   inflating: detectron2-master/projects/TridentNet/tridentnet/trident_backbone.py
#   inflating: detectron2-master/projects/TridentNet/tridentnet/trident_conv.py
#   inflating: detectron2-master/projects/TridentNet/tridentnet/trident_rcnn.py
#   inflating: detectron2-master/projects/TridentNet/tridentnet/trident_rpn.py
#   inflating: detectron2-master/setup.cfg
#   inflating: detectron2-master/setup.py
#    creating: detectron2-master/tests/
#   inflating: detectron2-master/tests/README.md
#  extracting: detectron2-master/tests/__init__.py
#   inflating: detectron2-master/tests/test_anchor_generator.py
#   inflating: detectron2-master/tests/test_box2box_transform.py
#   inflating: detectron2-master/tests/test_boxes.py
#   inflating: detectron2-master/tests/test_checkpoint.py
#   inflating: detectron2-master/tests/test_config.py
#   inflating: detectron2-master/tests/test_data_loader.py
#   inflating: detectron2-master/tests/test_data_transform.py
#   inflating: detectron2-master/tests/test_fast_rcnn.py
#   inflating: detectron2-master/tests/test_instances.py
#   inflating: detectron2-master/tests/test_mask_ops.py
#   inflating: detectron2-master/tests/test_model_analysis.py
#   inflating: detectron2-master/tests/test_model_e2e.py
#   inflating: detectron2-master/tests/test_model_zoo.py
#   inflating: detectron2-master/tests/test_nms_rotated.py
#   inflating: detectron2-master/tests/test_roi_align.py
#   inflating: detectron2-master/tests/test_roi_align_rotated.py
#   inflating: detectron2-master/tests/test_roi_heads.py
#   inflating: detectron2-master/tests/test_roi_pooler.py
#   inflating: detectron2-master/tests/test_rotated_boxes.py
#   inflating: detectron2-master/tests/test_rpn.py
#   inflating: detectron2-master/tests/test_sampler.py
#   inflating: detectron2-master/tests/test_visualizer.py
#    creating: detectron2-master/tools/
#   inflating: detectron2-master/tools/README.md
#   inflating: detectron2-master/tools/benchmark.py
#   inflating: detectron2-master/tools/convert-torchvision-to-d2.py
#    creating: detectron2-master/tools/deploy/
#   inflating: detectron2-master/tools/deploy/README.md
#   inflating: detectron2-master/tools/deploy/caffe2_converter.py
#   inflating: detectron2-master/tools/deploy/caffe2_mask_rcnn.cpp
#   inflating: detectron2-master/tools/plain_train_net.py
#   inflating: detectron2-master/tools/train_net.py
#   inflating: detectron2-master/tools/visualize_data.py
#   inflating: detectron2-master/tools/visualize_json_results.py
# finishing deferred symbolic links:
#   detectron2-master/docs/notes/contributing.md -> ../../.github/CONTRIBUTING.md
#   detectron2-master/docs/tutorials/getting_started.md -> ../../GETTING_STARTED.md
#   detectron2-master/docs/tutorials/install.md -> ../../INSTALL.md

# %%
#-----------------How to unzip 7z and tar files--------------------------
#!apt-get install p7zip-full
#!p7zip -d "/content/drive/My Drive/GUVI_Capstone/Synthetic Train Set (100k) - Detection & Recognition.tar.7z"
# !tar -xf"/content/drive/My Drive/GUVI_Capstone/Synthetic Train Set - Detection & Recognition.tar"
#!p7zip -d "/content/drive/My Drive/GUVI_Capstone/Synthetic Train Set (100k) - Detection & Recognition.tar.7z"
#!tar -xf "/content/Synthetic Train Set - Detection & Recognition.tar"

#-------To delete a folder--------------------
#!rm -rf 'Foldername'

# %%
# !wget https://github.com/bgshih/cocotext/releases/download/dl/cocotext.v2.zip

# %%
# !unzip cocotext.v2.zip

# %%
import random
import os
import numpy as np
import json
import itertools
import cv2
import torch
import shutil
import math
from tqdm import tqdm

from detectron2.data import DatasetCatalog, MetadataCatalog
from detectron2.engine import DefaultTrainer, DefaultPredictor
from detectron2.config import get_cfg
from detectron2.utils.visualizer import Visualizer, ColorMode
from google.colab.patches import cv2_imshow
from detectron2.structures import BoxMode

# %%
print(torch.cuda.device(0))
print(torch.cuda.get_device_name(0))
cuda0 = torch.device('cuda:0')

# %%
#This cell will split the data into Train and Validation

#Calibration for Train and Val split ratio
TrainTestSplit = 0.01

#Creating Train Folder
os.mkdir('/content/Synthetic Train Set - Detection & Recognition/Train')

#Moving data from folder 'Synthetic Train Set - Detection & Recognition' to Train
path = "/content/Synthetic Train Set - Detection & Recognition/"
moveto = "/content/Synthetic Train Set - Detection & Recognition/Train/"
files = os.listdir(path)
files.sort()
for f in files:
    if f == 'Train':
      pass
    else: 
      src = path+f
      dst = moveto+f
      shutil.move(src,dst)

#Creating folder structure for Val, same as Train
TrainAnno = '/content/Synthetic Train Set - Detection & Recognition/Train/Annotation'
TrainImg  = '/content/Synthetic Train Set - Detection & Recognition/Train/Image'
ValAnno = '/content/Synthetic Train Set - Detection & Recognition/Val/Annotation'
ValImg = '/content/Synthetic Train Set - Detection & Recognition/Val/Image'

for x in os.listdir(TrainAnno):
  os.makedirs(ValAnno+'/'+x)
for y in os.listdir(TrainImg):
  os.makedirs(ValImg+'/'+y)

#Split Dataset (images and annotations) to Train and Val
random.seed(0)
for i in os.listdir(TrainAnno):
    for m in random.sample(os.listdir(TrainAnno+'/'+i),math.ceil(len(os.listdir(TrainAnno+'/'+i))*TrainTestSplit)):
        shutil.move(TrainAnno+'/'+i+'/'+m,ValAnno+'/'+i+'/'+m)
        m1 = m[:-4]
        m1 = m1+'.jpg'
        shutil.move(TrainImg+'/'+i+'/'+m1,ValImg+'/'+i+'/'+m1)

# %%
def get_dicts(img_dir):
  basepath = img_dir+'/Image'
  annopath = img_dir+'/Annotation'
  dataset_dicts = []
  for folder in tqdm(os.listdir(basepath)):
    basepath1 = basepath+'/'+folder
    annopath1 = annopath+'/'+folder
    for entry in os.listdir(basepath1):
        record = {}
        record["file_name"] = (basepath1+'/'+entry)
        height, width = cv2.imread(basepath1+'/'+entry).shape[:2]
        record["height"] = height
        record["width"] = width
        record["image_id"] = entry
        dataset_dicts.append(record)
        #--------------Annotation Related -------------------------
        entry1 = entry[:-4]
        entry1 = entry1+'.txt'
        my_file = open(annopath1+'/'+ entry1, "r")
        content = my_file.read()
        content_list = content.split("\n")
        for i in content_list:
            if i == "":
              content_list.remove(i)
        #print(annos)
        temp_dicts = []
        for x in content_list:
            w = {}
            w = x.split(" ")
            temp_dicts.append(w)
        #print(temp_dicts)

        bx = []
        by = []
        ba = []
        for i in temp_dicts:
            ax = i[:4]
            ax = [float(j) for j in ax]
            bx.append(ax)
            ay = i[4:8]
            ay = [float(k) for k in ay]
            by.append(ay)
            aa = i[8:9]
            ba.append(aa)
        # print(temp_dicts)# print(bx)# print(by)# print(ba)
        px = []
        py = []
        pa = []
        objs = []
        for annox,annoy,annoz in zip(bx,by,ba):
            px = annox
            py = annoy
            pa = annoz
            poly = [(x + 0.5, y + 0.5) for x, y in zip(px, py)]
            poly = list(itertools.chain.from_iterable(poly))
            # print(px)# print(py)# print(poly)# print(pa)
            obj = {
                    "bbox": [np.min(px), np.min(py), np.max(px), np.max(py)],
                    "bbox_mode": BoxMode.XYXY_ABS,
                    "segmentation": [poly],
                    "category_id": 0,
                    "iscrowd": 0
            }
            objs.append(obj)
        record["annotations"] = objs
        dataset_dicts.append(record)
        my_file.close()
    #print(len(dataset_dicts))
        
  return (dataset_dicts)

# %%
for d in ["Train", "Val"]:
    DatasetCatalog.register("basepath_"+d, lambda d=d: get_dicts("/content/Synthetic Train Set - Detection & Recognition/"+d))
    MetadataCatalog.get("basepath_"+d).set(thing_classes=["H"])
My_metadata = MetadataCatalog.get("basepath_Train")

# %%
dataset_dicts = get_dicts('/content/Synthetic Train Set - Detection & Recognition/Train')

# %%
for d in random.sample(dataset_dicts, 3):
    img = cv2.imread(d["file_name"])
    print(d["file_name"])
    visualizer = Visualizer(img[:, :, ::-1], metadata=My_metadata, scale=0.5)
    vis = visualizer.draw_dataset_dict(d)
    cv2_imshow(vis.get_image()[:, :, ::-1])

# %%
cfg = get_cfg()
cfg.merge_from_file("/content/detectron2-master/configs/COCO-InstanceSegmentation/mask_rcnn_R_50_FPN_3x.yaml")
#cfg.merge_from_file("/content/detectron2-master/configs/COCO-InstanceSegmentation/mask_rcnn_R_101_FPN_3x.yaml")
cfg.DATASETS.TRAIN = ("basepath_Train",)
cfg.DATASETS.TEST = ()
cfg.DATALOADER.NUM_WORKERS = 2
cfg.MODEL.WEIGHTS = "detectron2://COCO-InstanceSegmentation/mask_rcnn_R_50_FPN_3x/137849600/model_final_f10217.pkl"  # Let training initialize from model zoo
#cfg.MODEL.WEIGHTS = "detectron2://COCO-InstanceSegmentation/mask_rcnn_R_101_FPN_3x/138205316/model_final_a3ec72.pkl"  # Let training initialize from model zoo
cfg.SOLVER.IMS_PER_BATCH = 2
cfg.SOLVER.BASE_LR = 0.01 # pick a good LR
cfg.SOLVER.MAX_ITER = 1000    # 300 iterations seems good enough for this toy dataset; you may need to train longer for a practical dataset
cfg.MODEL.ROI_HEADS.BATCH_SIZE_PER_IMAGE = 128   # faster, and good enough for this toy dataset (default: 512)
cfg.MODEL.ROI_HEADS.NUM_CLASSES = 1  # only has one class (Hindi Words)

os.makedirs(cfg.OUTPUT_DIR, exist_ok=True)
trainer = DefaultTrainer(cfg) 
trainer.resume_or_load(resume=False)
trainer.train()

# %%
# %reload_ext tensorboard
# %tensorboard --logdir output
#!kill 1201

# %%
cfg.MODEL.WEIGHTS = os.path.join(cfg.OUTPUT_DIR, "model_final.pth")
cfg.MODEL.ROI_HEADS.SCORE_THRESH_TEST = 0.3   # set the testing threshold for this model
cfg.DATASETS.TEST = ("basepath_Val", )
os.makedirs(cfg.OUTPUT_DIR, exist_ok=True)
predictor = DefaultPredictor(cfg)

# %%
p1 = '/content/Synthetic Train Set - Detection & Recognition/Train/Image'
x = 0
for i in os.listdir(p1):
  x = x + len(os.listdir(p1+'/'+i)) 

print(x)

# %%
from detectron2.utils.visualizer import ColorMode
dataset_dicts = get_dicts("/content/Synthetic Train Set - Detection & Recognition/Val")
for d in random.sample(dataset_dicts, 3):    
    im = cv2.imread(d["file_name"])
    outputs = predictor(im)
    v = Visualizer(im[:, :, ::-1],
                   metadata=My_metadata, 
                   scale=0.8, 
                   instance_mode=ColorMode.IMAGE_BW   # remove the colors of unsegmented pixels
    )
    v = v.draw_instance_predictions(outputs["instances"].to("cpu"))
    cv2_imshow(v.get_image()[:, :, ::-1])

# %%
from detectron2.evaluation import COCOEvaluator, inference_on_dataset
from detectron2.data import build_detection_test_loader
evaluator = COCOEvaluator("basepath_Val", cfg, False, output_dir="./output/")
val_loader = build_detection_test_loader(cfg, "basepath_Val")
inference_on_dataset(trainer.model, val_loader, evaluator)

# %%
print(dataset_dicts[0])
